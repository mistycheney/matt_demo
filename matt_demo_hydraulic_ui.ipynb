# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from matt_demo import *

# %% [markdown]
# ### Training MATT with paired (time series, text) data

# %%
data = load_data('hydraulic')

# %%
train_model(data, output_model='hydraulic.model')
# Out:
# Training hydraulic.model using provided data...
# Training finished.

# %% [markdown]
# ### Load MATT Model

# %%
model = load_model('hydraulic.model')
# Out:
# Loaded hydraulic.model

# %% [markdown]
# ### Explaining Unseen Time Series in Natural Language

# %%
display_expl_widgets(model)

# %% [markdown]
# ### Descriptive Search for Historical Time Series

# %%
display_search_widgets(model)
